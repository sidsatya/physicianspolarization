# %%
import pandas as pd
import numpy as np

# %%
sahie_2008 = pd.read_csv('../data/county_insurance_rates/sahie_2008.csv', skiprows=79)
sahie_2009 = pd.read_csv('../data/county_insurance_rates/sahie_2009.csv', skiprows=79)
sahie_2010 = pd.read_csv('../data/county_insurance_rates/sahie_2010.csv', skiprows=79)
sahie_2011 = pd.read_csv('../data/county_insurance_rates/sahie_2011.csv', skiprows=79)
sahie_2012 = pd.read_csv('../data/county_insurance_rates/sahie_2012.csv', skiprows=79)
sahie_2013 = pd.read_csv('../data/county_insurance_rates/sahie_2013.csv', skiprows=79)
sahie_2014 = pd.read_csv('../data/county_insurance_rates/sahie_2014.csv', skiprows=79)
sahie_2015 = pd.read_csv('../data/county_insurance_rates/sahie_2015.csv', skiprows=79)
sahie_2016 = pd.read_csv('../data/county_insurance_rates/sahie_2016.csv', skiprows=79)
sahie_2017 = pd.read_csv('../data/county_insurance_rates/sahie_2017.csv', skiprows=79)
sahie_2018 = pd.read_csv('../data/county_insurance_rates/sahie_2018.csv', skiprows=79)
sahie_2019 = pd.read_csv('../data/county_insurance_rates/sahie_2019.csv', skiprows=79)
sahie_2020 = pd.read_csv('../data/county_insurance_rates/sahie_2020.csv', skiprows=79)
sahie_2021 = pd.read_csv('../data/county_insurance_rates/sahie_2021.csv', skiprows=85)
sahie_2022 = pd.read_csv('../data/county_insurance_rates/sahie_2022.csv', skiprows=85)
sahie_2023 = pd.read_csv('../data/county_insurance_rates/sahie_2023.csv', skiprows=85)
# Out:
# /var/folders/y2/820f0d093ps3xgsy472nf3zc0000gn/T/ipykernel_19752/1447258837.py:1: DtypeWarning: Columns (0:   NIPR, 1:  nipr_moe, 2:    NUI, 3:   nui_moe, 4: NIC, 5: nic_moe, 6: PCTUI, 7: pctui_moe, 8: PCTIC, 9: pctic_moe, 10: PCTELIG, 11: pctelig_moe, 12: PCTLIIC, 13: pctliic_moe) have mixed types. Specify dtype option on import or set low_memory=False.
#   sahie_2008 = pd.read_csv('../data/county_insurance_rates/sahie_2008.csv', skiprows=79)
# /var/folders/y2/820f0d093ps3xgsy472nf3zc0000gn/T/ipykernel_19752/1447258837.py:2: DtypeWarning: Columns (0: NIPR, 1: nipr_moe, 2: NUI, 3: nui_moe, 4: NIC, 5: nic_moe, 6: PCTUI, 7: pctui_moe, 8: PCTIC, 9: pctic_moe, 10: PCTELIG, 11: pctelig_moe, 12: PCTLIIC, 13: pctliic_moe) have mixed types. Specify dtype option on import or set low_memory=False.
#   sahie_2009 = pd.read_csv('../data/county_insurance_rates/sahie_2009.csv', skiprows=79)
#         year   version  statefips  countyfips  geocat  agecat  racecat  \
# ...

# %%
# Filtering steps
# 1. Filter to geocat == 50 for counties 
# 2. Baseline uninsured: agecat = 1 (18-64), racecat = 0, sexcat = 0, iprcat = 0
#   - PCTUI = percent uninsured among all under-65 county adults, NUI/NIPR is another way to construct this
# 3. ACA-targeted population: agecat = 1 (18-64), racecat = 0, sexcat = 0, iprcat = 3 (at or below 138% of poverty)
#   - PCTUI = uninsured rate among the <= 138% FPT 18-65 group, NUI/NIPR is another way to construct this
